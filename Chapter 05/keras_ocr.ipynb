# %%
# !pip install -q keras-ocr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 KB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.2/608.2 KB 18.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 62.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 1.7 MB/s eta 0:00:00
#   Building wheel for validators (setup.py) ... done

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Downloading /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# Downloading /root/.keras-ocr/crnn_kurapan.h5

# %%
images = [
          keras_ocr.tools.read(img) for img in ['2.png',
                                                '4.png'
                                                ]
]

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize=(10,20))
plt.imshow(images[0])

# %%
plt.imshow(images[1])

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# 1/1 [==============================] - 8s 8s/step
# 6/6 [==============================] - 1s 190ms/step

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
  keras_ocr.tools.drawAnnotations(image=image,
                                  predictions=predictions,
                                  ax=ax
                                  )

# %%
prediction_groups
# Out:
# [[('blan', array([[334.,   9.],
#           [414.,   9.],
#           [414.,  37.],
#           [334.,  37.]], dtype=float32)), ('calnes', array([[450.,  15.],
#           [477.,  15.],
#           [477.,  21.],
#           [450.,  21.]], dtype=float32)), ('to', array([[481.,  15.],
#           [490.,  15.],
#           [490.,  21.],
#           [481.,  21.]], dtype=float32)), ('ons', array([[521.,  15.],
#           [544.,  15.],
#           [544.,  21.],
#           [521.,  21.]], dtype=float32)), ('ron', array([[544.,  15.],
#           [558.,  15.],
#           [558.,  21.],
#           [544.,  21.]], dtype=float32)), ('aio', array([[558.,  15.],
#           [578.,  15.],
#           [578.,  22.],
#           [558.,  22.]], dtype=float32)), ('falie',
#    array([[468.05887 ,  32.764713],
#           [494.3326  ,  34.015842],
#           [493.98874 ,  41.23756 ],
#           [467.715   ,  39.98643 ]], dtype=float32)), ('ol',
#    array([[451.,  34.],
#           [468.,  34.],
#           [468.,  41.],
#           [451.,  41.]], dtype=float32)), ('sued', array([[455.,  43.],
#           [485.,  43.],
#           [485.,  49.],
#           [455.,  49.]], dtype=float32)), ('', array([[485.,  43.],
#           [495.,  43.],
#           [495.,  49.],
#           [485.,  49.]], dtype=float32)), ('o', array([[495.,  43.],
#           [504.,  43.],
#           [504.,  50.],
#           [495.,  50.]], dtype=float32)), ('nigh', array([[339.,  47.],
#           [362.,  47.],
#           [362.,  56.],
#           [339.,  56.]], dtype=float32)), ('n', array([[363.,  48.],
#           [374.,  48.],
#           [374.,  56.],
#           [363.,  56.]], dtype=float32)), ('fiber', array([[375.,  49.],
#           [401.,  49.],
#           [401.,  56.],
#           [375.,  56.]], dtype=float32)), ('1ed', array([[ 7., 49.],
#           [26., 49.],
#           [26., 59.],
#           [ 7., 59.]], dtype=float32)), ('tolal', array([[69., 50.],
#           [87., 50.],
#           [87., 56.],
#           [69., 56.]], dtype=float32)), ('aliss', array([[ 88.,  50.],
#           [114.,  50.],
#           [114.,  57.],
#           [ 88.,  57.]], dtype=float32)), ('haloa',
#    array([[472.1675  ,  50.654823],
#           [492.4924  ,  52.106598],
#           [491.97464 ,  59.35533 ],
#           [471.64975 ,  57.903557]], dtype=float32)), ('ror',
#    array([[456.,  52.],
#           [472.,  52.],
#           [472.,  58.],
#           [456.,  58.]], dtype=float32)), ('soona', array([[ 72.,  60.],
#           [101.,  60.],
#           [101.,  66.],
#           [ 72.,  66.]], dtype=float32)), ('alon', array([[103.,  60.],
#           [122.,  60.],
#           [122.,  68.],
#           [103.,  68.]], dtype=float32)), ('cholesterol', array([[451.,  60.],
#           [490.,  60.],
#           [490.,  67.],
#           [451.,  67.]], dtype=float32)), ('nutrition', array([[321.,  60.],
#           [377.,  60.],
#           [377.,  71.],
#           [321.,  71.]], dtype=float32)), ('ume', array([[491.,  61.],
#           [505.,  61.],
#           [505.,  68.],
#           [491.,  68.]], dtype=float32)), ('facts', array([[381.,  61.],
#           [416.,  61.],
#           [416.,  71.],
#           [381.,  71.]], dtype=float32)), ('cdlum', array([[453.,  69.],
#           [477.,  69.],
#           [477.,  76.],
#           [453.,  76.]], dtype=float32)), ('tos', array([[73., 70.],
#           [89., 70.],
#           [89., 77.],
#           [73., 77.]], dtype=float32)), ('ma', array([[478.,  70.],
#           [491.,  70.],
#           [491.,  76.],
#           [478.,  76.]], dtype=float32)), ('aleo', array([[ 90.,  71.],
#           [110.,  71.],
#           [110.,  78.],
#           [ 90.,  78.]], dtype=float32)), ('cue',
#    array([[388.18463 ,  70.52309 ],
#           [400.61542 ,  72.076935],
#           [399.80005 ,  78.600006],
#           [387.36926 ,  77.04616 ]], dtype=float32)), ('ctater',
#    array([[358.,  77.],
#           [384.,  77.],
#           [384.,  84.],
#           [358.,  84.]], dtype=float32)), ('total', array([[452.,  78.],
#           [469.,  78.],
#           [469.,  85.],
#           [452.,  85.]], dtype=float32)), ('carbohydrale', array([[470.,  78.],
#           [515.,  78.],
#           [515.,  85.],
#           [470.,  85.]], dtype=float32)), ('ponsmeles', array([[ 73.,  80.],
#           [121.,  80.],
#           [121.,  88.],
#           [ 73.,  88.]], dtype=float32)), ('fu', array([[121.,  81.],
#           [132.,  81.],
#           [132.,  87.],
#           [121.,  87.]], dtype=float32)), ('oes', array([[131.,  81.],
#           [146.,  81.],
#           [146.,  88.],
#           [131.,  88.]], dtype=float32)), ('dga', array([[457.,  87.],
#           [478.,  87.],
#           [478.,  94.],
#           [457.,  94.]], dtype=float32)), ('nel',
#    array([[478.25745 ,  86.425735],
#           [494.49506 ,  88.0495  ],
#           [493.8416  ,  94.58415 ],
#           [477.604   ,  92.96039 ]], dtype=float32)), ('s',
#    array([[495.,  88.],
#           [503.,  88.],
#           [503.,  94.],
#           [495.,  94.]], dtype=float32)), ('sononealale', array([[ 73.,  91.],
#           [125.,  91.],
#           [125.,  98.],
#           [ 73.,  98.]], dtype=float32)), ('re', array([[125.,  92.],
#           [136.,  92.],
#           [136.,  98.],
#           [125.,  98.]], dtype=float32)), ('a', array([[137.,  92.],
#           [145.,  92.],
#           [145.,  99.],
#           [137.,  99.]], dtype=float32)), ('xd', array([[  7.,  92.],
#           [ 27.,  92.],
#           [ 27., 102.],
#           [  7., 102.]], dtype=float32)), ('suged',
#    array([[457.01947 ,  95.68872 ],
#           [478.31128 ,  97.019455],
#           [477.8249  , 104.80156 ],
#           [456.53308 , 103.470825]], dtype=float32)), ('s',
#    array([[480.,  97.],
#           [487.,  97.],
#           [487., 103.],
#           [480., 103.]], dtype=float32)), ('chole', array([[ 68., 101.],
#           [ 89., 101.],
#           [ 89., 108.],
#           [ 68., 108.]], dtype=float32)), ('sterol', array([[ 88., 102.],
#           [110., 102.],
#           [110., 108.],
#           [ 88., 108.]], dtype=float32)), ('oma',
#    array([[111.03962 , 101.603966],
#           [125.39605 , 103.039604],
#           [124.76238 , 109.37624 ],
#           [110.40595 , 107.940605]], dtype=float32)), ('caoties',
#    array([[322., 103.],
#           [346., 103.],
#           [346., 109.],
#           [322., 109.]], dtype=float32)), ('fo', array([[378., 103.],
#           [389., 103.],
#           [389., 110.],
#           [378., 110.]], dtype=float32)), ('o', array([[399., 104.],
#           [411., 104.],
#           [411., 110.],
#           [399., 110.]], dtype=float32)), ('roloin', array([[453., 105.],
#           [477., 105.],
#           [477., 112.],
#           [453., 112.]], dtype=float32)), ('a', array([[478., 105.],
#           [487., 105.],
#           [487., 112.],
#           [478., 112.]], dtype=float32)), ('lonee',
#    array([[330.131  , 110.4276 ],
#           [348.50345, 111.95863],
#           [347.95865, 118.49657],
#           [329.5862 , 116.96553]], dtype=float32)), ('soalon',
#    array([[ 68., 112.],
#           [ 95., 112.],
#           [ 95., 118.],
#           [ 68., 118.]], dtype=float32)), ('oo', array([[ 97.2439 , 110.80487],
#           [118.53659, 113.17073],
#           [117.78049, 119.97562],
#           [ 96.48779, 117.60976]], dtype=float32)), ('ror',
#    array([[349., 112.],
#           [363., 112.],
#           [363., 118.],
#           [349., 118.]], dtype=float32)), ('nil', array([[363., 112.],
#           [373., 112.],
#           [373., 118.],
#           [363., 118.]], dtype=float32)), ('o', array([[381., 112.],
#           [389., 112.],
#           [389., 118.],
#           [381., 118.]], dtype=float32)), ('mncos', array([[548., 120.],
#           [579., 120.],
#           [579., 127.],
#           [548., 127.]], dtype=float32)), ('donne', array([[455., 121.],
#           [481., 121.],
#           [481., 128.],
#           [455., 128.]], dtype=float32)), ('oa', array([[480., 121.],
#           [492., 121.],
#           [492., 128.],
#           [480., 128.]], dtype=float32)), ('otaecium', array([[ 69., 122.],
#           [107., 122.],
#           [107., 129.],
#           [ 69., 129.]], dtype=float32)), ('ceng', array([[108., 123.],
#           [126., 123.],
#           [126., 130.],
#           [108., 130.]], dtype=float32)), ('total', array([[322., 129.],
#           [337., 129.],
#           [337., 135.],
#           [322., 135.]], dtype=float32)), ('fal', array([[337., 129.],
#           [348., 129.],
#           [348., 135.],
#           [337., 135.]], dtype=float32)), ('enoe', array([[543., 129.],
#           [563., 129.],
#           [563., 135.],
#           [543., 135.]], dtype=float32)), ('aou', array([[453., 130.],
#           [477., 130.],
#           [477., 136.],
#           [453., 136.]], dtype=float32)), ('carbonydote',
#    array([[ 89.04683, 131.50146],
#           [138.15512, 133.0361 ],
#           [137.91512, 140.7161 ],
#           [ 88.80682, 139.18146]], dtype=float32)), ('totel',
#    array([[ 69., 133.],
#           [ 88., 133.],
#           [ 88., 139.],
#           [ 69., 139.]], dtype=float32)), ('14', array([[139., 133.],
#           [151., 133.],
#           [151., 140.],
#           [139., 140.]], dtype=float32)), ('xid', array([[  7., 135.],
#           [ 27., 135.],
#           [ 27., 145.],
#           [  7., 145.]], dtype=float32)), ('o', array([[362., 137.],
#           [371., 137.],
#           [371., 144.],
#           [362., 144.]], dtype=float32)), ('le', array([[543., 138.],
#           [549., 138.],
#           [549., 142.],
#           [543., 142.]], dtype=float32)), ('datly', array([[ 74., 143.],
#           [ 96., 143.],
#           [ 96., 149.],
#           [ 74., 149.]], dtype=float32)), ('fcer', array([[ 96., 143.],
#           [113., 143.],
#           [113., 149.],
#           [ 96., 149.]], dtype=float32)), ('54', array([[113., 143.],
#           [122., 143.],
#           [122., 150.],
#           [113., 150.]], dtype=float32)), ('eono',
#    array([[540.09393, 143.21545],
#           [563.1878 , 144.43094],
#           [562.93646, 149.20718],
#           [539.8426 , 147.9917 ]], dtype=float32)), ('crsey',
#    array([[328., 146.],
#           [351., 146.],
#           [351., 152.],
#           [328., 152.]], dtype=float32)), ('oo', array([[351., 146.],
#           [360., 146.],
#           [360., 152.],
#           [351., 152.]], dtype=float32)), ('sur',
#    array([[ 74.019455, 152.68872 ],
#           [ 96.24513 , 154.07782 ],
#           [ 95.76654 , 161.73541 ],
#           [ 73.54086 , 160.34631 ]], dtype=float32)), ('ino',
#    array([[352., 154.],
#           [366., 154.],
#           [366., 161.],
#           [352., 161.]], dtype=float32)), ('al', array([[366., 154.],
#           [375., 154.],
#           [375., 161.],
#           [366., 161.]], dtype=float32)), ('d', array([[375., 155.],
#           [382., 155.],
#           [382., 161.],
#           [375., 161.]], dtype=float32)), ('treloln', array([[ 70., 163.],
#           [ 96., 163.],
#           [ 96., 170.],
#           [ 70., 170.]], dtype=float32)), ('te',
#    array([[112.13936 , 162.46724 ],
#           [127.467224, 163.86067 ],
#           [126.87706 , 170.35246 ],
#           [111.549194, 168.95903 ]], dtype=float32)), ('1s',
#    array([[127., 163.],
#           [136., 163.],
#           [136., 170.],
#           [127., 170.]], dtype=float32)), ('crenld', array([[339., 163.],
#           [369., 163.],
#           [369., 169.],
#           [339., 169.]], dtype=float32)), ('l', array([[369., 163.],
#           [378., 163.],
#           [378., 169.],
#           [369., 169.]], dtype=float32)), ('d', array([[378., 163.],
#           [385., 163.],
#           [385., 170.],
#           [378., 170.]], dtype=float32)), ('dues', array([[ 97., 164.],
#           [112., 164.],
#           [112., 169.],
#           [ 97., 169.]], dtype=float32)), ('ctosotd', array([[322., 171.],
#           [355., 171.],
#           [355., 178.],
#           [322., 178.]], dtype=float32)), ('', array([[356.07693, 171.38461],
#           [369.6154 , 173.07693],
#           [368.8154 , 179.47693],
#           [355.27695, 177.7846 ]], dtype=float32)), ('con',
#    array([[151., 178.],
#           [166., 178.],
#           [166., 185.],
#           [151., 185.]], dtype=float32)), ('xid', array([[  7., 178.],
#           [ 27., 178.],
#           [ 27., 188.],
#           [  7., 188.]], dtype=float32)), ('um',
#    array([[ 71.030975, 178.53543 ],
#           [ 93.26549 , 180.01773 ],
#           [ 92.884964, 185.72571 ],
#           [ 70.65045 , 184.24341 ]], dtype=float32)), ('a',
#    array([[ 93., 179.],
#           [ 99., 179.],
#           [ 99., 185.],
#           [ 93., 185.]], dtype=float32)), ('o', array([[ 99., 179.],
#           [110., 179.],
#           [110., 185.],
#           [ 99., 185.]], dtype=float32)), ('diemo', array([[128., 179.],
#           [150., 179.],
#           [150., 185.],
#           [128., 185.]], dtype=float32)), ('tom',
#    array([[347.19513, 179.24388],
#           [364.53662, 181.1707 ],
#           [363.8415 , 187.4268 ],
#           [346.5    , 185.49998]], dtype=float32)), ('c', array([[464., 187.],
#           [480., 187.],
#           [480., 191.],
#           [464., 191.]], dtype=float32)), ('eoson', array([[326., 188.],
#           [351., 188.],
#           [351., 195.],
#           [326., 195.]], dtype=float32)), ('satg', array([[355., 188.],
#           [373., 188.],
#           [373., 195.],
#           [355., 195.]], dtype=float32)), ('caoun', array([[ 71., 189.],
#           [ 94., 189.],
#           [ 94., 195.],
#           [ 71., 195.]], dtype=float32)), ('lon', array([[129., 189.],
#           [141., 189.],
#           [141., 195.],
#           [129., 195.]], dtype=float32)), ('', array([[230., 189.],
#           [237., 189.],
#           [237., 280.],
#           [230., 280.]], dtype=float32)), ('', array([[223., 190.],
#           [230., 190.],
#           [230., 281.],
#           [223., 281.]], dtype=float32)), ('cacirene', array([[335., 197.],
#           [369., 197.],
#           [369., 204.],
#           [335., 204.]], dtype=float32)), ('deat', array([[326., 205.],
#           [346., 205.],
#           [346., 212.],
#           [326., 212.]], dtype=float32)), ('bar', array([[350., 206.],
#           [361., 206.],
#           [361., 212.],
#           [350., 212.]], dtype=float32)), ('o', array([[361., 206.],
#           [370., 206.],
#           [370., 213.],
#           [361., 213.]], dtype=float32)), ('t', array([[333., 215.],
#           [346., 215.],
#           [346., 221.],
#           [333., 221.]], dtype=float32)), ('s', array([[473., 221.],
#           [485., 221.],
#           [485., 225.],
#           [473., 225.]], dtype=float32)), ('ead', array([[  8., 221.],
#           [ 27., 221.],
#           [ 27., 231.],
#           [  8., 231.]], dtype=float32)), ('pieeid', array([[322., 223.],
#           [343., 223.],
#           [343., 229.],
#           [322., 229.]], dtype=float32)), ('do', array([[515.0565 , 225.81223],
#           [540.19006, 227.00906],
#           [539.92993, 232.47287],
#           [514.7964 , 231.27603]], dtype=float32)), ('ta', array([[558., 226.],
#           [570., 226.],
#           [570., 231.],
#           [558., 231.]], dtype=float32)), ('don', array([[571., 226.],
#           [584., 226.],
#           [584., 232.],
#           [571., 232.]], dtype=float32)), ('e', array([[479., 227.],
#           [488., 227.],
#           [488., 233.],
#           [479., 233.]], dtype=float32)), ('li', array([[502., 227.],
#           [514., 227.],
#           [514., 232.],
#           [502., 232.]], dtype=float32)), ('i', array([[481., 233.],
#           [495., 233.],
#           [495., 238.],
#           [481., 238.]], dtype=float32)), ('tie', array([[519., 233.],
#           [533., 233.],
#           [533., 238.],
#           [519., 238.]], dtype=float32)), ('alemne', array([[322., 237.],
#           [348., 237.],
#           [348., 241.],
#           [322., 241.]], dtype=float32)), ('e', array([[269.48495, 236.51341],
#           [280.81937, 237.1611 ],
#           [276.6924 , 309.3824 ],
#           [265.358  , 308.7347 ]], dtype=float32)), ('st', array([[504., 238.],
#           [515., 238.],
#           [515., 244.],
#           [504., 244.]], dtype=float32)), ('cn', array([[515., 238.],
#           [534., 238.],
#           [534., 243.],
#           [515., 243.]], dtype=float32)), ('oat', array([[479., 239.],
#           [488., 239.],
#           [488., 243.],
#           [479., 243.]], dtype=float32)), ('de', array([[489., 239.],
#           [502., 239.],
#           [502., 243.],
#           [489., 243.]], dtype=float32)), ('amn', array([[326., 244.],
#           [343., 244.],
#           [343., 250.],
#           [326., 250.]], dtype=float32)), ('wheat', array([[519., 244.],
#           [553., 244.],
#           [553., 255.],
#           [519., 255.]], dtype=float32)), ('oats', array([[554., 244.],
#           [580., 244.],
#           [580., 255.],
#           [554., 255.]], dtype=float32)), ('contains', array([[451., 245.],
#           [498., 245.],
#           [498., 255.],
#           [451., 255.]], dtype=float32)), ('rye', array([[499., 245.],
#           [518., 245.],
#           [518., 255.],
#           [499., 255.]], dtype=float32)), ('juam', array([[323., 252.],
#           [344., 252.],
#           [344., 258.],
#           [323., 258.]], dtype=float32)), ('glutent', array([[451., 255.],
#           [493., 255.],
#           [493., 265.],
#           [451., 265.]], dtype=float32)), ('fid', array([[  8., 265.],
#           [ 27., 265.],
#           [ 27., 275.],
#           [  8., 275.]], dtype=float32)), ('contain',
#    array([[469.61008, 265.86118],
#           [506.9011 , 264.4269 ],
#           [507.34567, 275.98672],
#           [470.05466, 277.421  ]], dtype=float32)), ('sesame',
#    array([[508., 265.],
#           [539., 265.],
#           [539., 276.],
#           [508., 276.]], dtype=float32)), ('seeds', array([[539., 265.],
#           [566., 265.],
#           [566., 276.],
#           [539., 276.]], dtype=float32)), ('soya', array([[567., 265.],
#           [590., 265.],
#           [590., 276.],
#           [567., 276.]], dtype=float32)), ('atn', array([[326., 267.],
#           [345., 267.],
#           [345., 273.],
#           [326., 273.]], dtype=float32)), ('l', array([[344., 267.],
#           [349., 267.],
#           [349., 273.],
#           [344., 273.]], dtype=float32)), ('may', array([[452., 266.],
#           [470., 266.],
#           [470., 276.],
#           [452., 276.]], dtype=float32)), ('lamn', array([[324., 275.],
#           [344., 275.],
#           [344., 281.],
#           [324., 281.]], dtype=float32)), ('s', array([[230., 281.],
#           [237., 281.],
#           [237., 299.],
#           [230., 299.]], dtype=float32)), ('', array([[223., 283.],
#           [229., 283.],
#           [229., 311.],
#           [223., 311.]], dtype=float32)), ('jo', array([[322., 283.],
#           [332., 283.],
#           [332., 288.],
#           [322., 288.]], dtype=float32)), ('lcn', array([[333., 283.],
#           [350., 283.],
#           [350., 289.],
#           [333., 289.]], dtype=float32)), ('sgin', array([[515., 287.],
#           [529., 287.],
#           [529., 293.],
#           [515., 293.]], dtype=float32)), ('a', array([[529., 288.],
#           [541., 288.],
#           [541., 293.],
#           [529., 293.]], dtype=float32)), ('se', array([[540., 288.],
#           [560., 288.],
#           [560., 294.],
#           [540., 294.]], dtype=float32)), ('va', array([[458., 291.],
#           [464., 291.],
#           [464., 295.],
#           [458., 295.]], dtype=float32)), ('s', array([[230., 299.],
#           [238., 299.],
#           [238., 320.],
#           [230., 320.]], dtype=float32)), ('g', array([[267., 307.],
#           [278., 307.],
#           [278., 323.],
#           [267., 323.]], dtype=float32)), ('red', array([[  7., 308.],
#           [ 27., 308.],
#           [ 27., 318.],
#           [  7., 318.]], dtype=float32)), ('1200', array([[451., 329.],
#           [476., 329.],
#           [476., 340.],
#           [451., 340.]], dtype=float32)), ('1700', array([[537., 329.],
#           [563., 329.],
#           [563., 340.],
#           [537., 340.]], dtype=float32)), ('xd', array([[111., 330.],
#           [130., 330.],
#           [130., 339.],
#           [111., 339.]], dtype=float32)), ('d', array([[207., 330.],
#           [216., 330.],
#           [216., 339.],
#           [207., 339.]], dtype=float32)), ('d', array([[296., 332.],
#           [302., 332.],
#           [302., 339.],
#           [296., 339.]], dtype=float32))],
#  [('this', array([[ 30.,  45.],
#           [147.,  45.],
#           [147.,  93.],
#           [ 30.,  93.]], dtype=float32)),
#   ('hanowntten', array([[312.2559  ,  52.215122],
#           [593.51117 ,  44.40247 ],
#           [594.724   ,  88.06323 ],
#           [313.4687  ,  95.875885]], dtype=float32)),
#   ('s', array([[181.,  53.],
#           [210.,  53.],
#           [210.,  89.],
#           [181.,  89.]], dtype=float32)),
#   ('c', array([[255.,  64.],
#           [283.,  64.],
#           [283.,  90.],
#           [255.,  90.]], dtype=float32)),
#   ('example', array([[ 39.833397, 150.42717 ],
#           [234.79642 , 138.80684 ],
#           [237.95755 , 191.84361 ],
#           [ 42.994537, 203.46394 ]], dtype=float32)),
#   ('wrile', array([[ 40.999992, 239.      ],
#           [156.99997 , 239.      ],
#           [156.99997 , 281.      ],
#           [ 40.999992, 281.      ]], dtype=float32)),
#   ('joood', array([[270.42035, 256.94684],
#           [382.46295, 239.60692],
#           [390.17297, 289.4256 ],
#           [278.13037, 306.7655 ]], dtype=float32)),
#   ('cava', array([[592.2672 , 250.25061],
#           [683.8136 , 253.40738],
#           [682.8314 , 281.89075],
#           [591.28503, 278.73398]], dtype=float32)),
#   ('as', array([[408., 252.],
#           [457., 252.],
#           [457., 280.],
#           [408., 280.]], dtype=float32)),
#   ('you', array([[487.783  , 259.07507],
#           [570.47266, 247.7992 ],
#           [576.79517, 294.1643 ],
#           [494.10547, 305.4402 ]], dtype=float32)),
#   ('os', array([[195., 254.],
#           [247., 254.],
#           [247., 283.],
#           [195., 283.]], dtype=float32))]]

# %%
prediction_groups[0][0][0]
# Out:
# 'blan'

# %%
for i in range(len(prediction_groups)):
  print("image:",  i)
  for j in range(len(prediction_groups[i])):
    #print(j)
    print(prediction_groups[i][j][0])
# Out:
# image: 0
# blan
# calnes
# to
# ons
# ron
# aio
# falie
# ol
# sued
#
# o
# nigh
# n
# fiber
# 1ed
# tolal
# aliss
# haloa
# ror
# soona
# alon
# cholesterol
# nutrition
# ume
# facts
# cdlum
# tos
# ma
# aleo
# cue
# ctater
# total
# carbohydrale
# ponsmeles
# fu
# oes
# dga
# nel
# s
# sononealale
# re
# a
# xd
# suged
# s
# chole
# sterol
# oma
# caoties
# fo
# o
# roloin
# a
# lonee
# soalon
# oo
# ror
# nil
# o
# mncos
# donne
# oa
# otaecium
# ceng
# total
# fal
# enoe
# aou
# carbonydote
# totel
# 14
# xid
# o
# le
# datly
# fcer
# 54
# eono
# crsey
# oo
# sur
# ino
# al
# d
# treloln
# te
# 1s
# crenld
# l
# d
# dues
# ctosotd
#
# con
# xid
# um
# a
# o
# diemo
# tom
# c
# eoson
# satg
# caoun
# lon
#
#
# cacirene
# deat
# bar
# o
# t
# s
# ead
# pieeid
# do
# ta
# don
# e
# li
# i
# tie
# alemne
# e
# st
# cn
# oat
# de
# amn
# wheat
# oats
# contains
# rye
# juam
# glutent
# fid
# contain
# sesame
# seeds
# soya
# atn
# l
# may
# lamn
# s
#
# jo
# lcn
# sgin
# a
# se
# va
# s
# g
# red
# 1200
# 1700
# xd
# d
# d
# image: 1
# this
# hanowntten
# s
# c
# example
# wrile
# joood
# cava
# as
# you
# os
